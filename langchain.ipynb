# %%
from langchain.document_loaders import WebBaseLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.memory import ConversationBufferMemory
from langchain.llms import OpenAI
from langchain.chains import ConversationalRetrievalChain
from langchain.chat_models import ChatOpenAI
import config

# %%
api_key = config.api_key

# %%
url = "https://365datascience.com/upcoming-courses"

# %%
loader = WebBaseLoader(url)
print(loader)
# Out:
# <langchain.document_loaders.web_base.WebBaseLoader object at 0x0000015C73839A90>

# %%
raw_documents = loader.load()
raw_documents
# Out:
# [Document(page_content="\n\n\nOnline Data Science Courses and Certification – 365 Data Science\n\n\n\n  \n          Courses\n         \n          Learning Paths  Learning Paths\n             \n                Career Paths  Career Paths\n                   See all  Career Paths See all  \n                        Data analyst\n                      \n                        Data scientist\n                      \n                        Business analyst\n                      \n                        Senior data analyst\n                      \n                        Senior data scientist\n                      \n                        Tableau developer\n                      \n                        Power BI developer\n                      \n                        Data engineer\n                      \n                        Machine learning scientist\n                      \n                        AI engineer\n                       \n                    Not sure?\n                   Take a career quiz  \n                Bootcamp\n               We are accredited by  \n          Resources  Resources\n             \n                Projects\n               \n                Career Kit  Career Kit\n                   Career Kit \n                        Interview Simulator\n                       \n                        Career Quiz\n                       \n                        Career Guides\n                       \n                Study Kit  Study Kit\n                   Study Kit \n                        Flashcards\n                       \n                        Course Notes\n                       \n                        Practice Exams\n                       \n                        Infographics\n                       \n                        Coding Templates\n                       \n                Blog\n               \n          Student Outcomes  Student Outcomes\n             \n                Reviews\n               \n                Student Stories\n               \n                Student Outcomes Report\n               \n          Pricing\n         \n          For Business\n         \n          Log in\n         \n          Start free\n           \n            Courses Library\n           \n            Discover a content-rich data science curriculum designed to build your skillset from\n            beginner to job-ready and help you achieve your data science career goals.\n            \n    Filter by\n   \n          Topics\n          Data LiteracyData PreprocessingData AnalysisMachine and Deep LearningAIData VisualizationProgrammingMath & StatisticsBusiness SkillsFinance SkillsData EngineeringCareer DevelopmentDashboard ReportingSpreadsheetsIndustry SpecializationSoft skillsFinance TheoryCloud ComputingMLOps \n          Technology\n          pythonSQLrexceltableauPower BIgittheorygoogle sheetsChatGPTLangChainapache airflowLangGraphAWScopilot \n          Level of difficulty\n          BasicIntermediateAdvanced \n          Duration\n          1-2 hours3-4 hours5-6 hours7+ hours \n          Career Track\n          Data ScientistData AnalystBusiness AnalystAI EngineerData EngineerSenior Data AnalystTableau DeveloperPower BI DeveloperMachine Learning ScientistSenior Data Scientist      \n      120 results\n    \n    \n          bestseller\n   \n            Introduction to Data and Data Science\n           \n            with Martin Ganchev, Iliya Valchanov\n           4.8/5                 (17,562)  \n            3 hours of content\n                 trending topic\n   \n            Intro to AI\n           \n            with Ned Krastev\n           4.9/5                 (1,720)  \n            2 hours of content\n                  \n            AI Strategy\n           \n            with Bernard Marr\n           0/5                   \n            4 hours of content\n                  \n            Intro to AI Agents and Agentic AI\n           \n            with Ned Krastev\n           4.8/5               ...

# %%
text_splitter = RecursiveCharacterTextSplitter()
documents = text_splitter.split_documents(raw_documents)
documents
# Out:
# [Document(page_content='Online Data Science Courses and Certification – 365 Data Science', metadata={'source': 'https://365datascience.com/upcoming-courses', 'title': 'Online Data Science Courses and Certification – 365 Data Science', 'description': 'Browse various data science courses on in-demand tools like SQL, Python, and R. Discover the perfect structured training program for beginners. Start now!', 'language': 'en'}),
#  Document(page_content='Courses\n         \n          Learning Paths  Learning Paths\n             \n                Career Paths  Career Paths\n                   See all  Career Paths See all  \n                        Data analyst\n                      \n                        Data scientist\n                      \n                        Business analyst\n                      \n                        Senior data analyst\n                      \n                        Senior data scientist\n                      \n                        Tableau developer\n                      \n                        Power BI developer\n                      \n                        Data engineer\n                      \n                        Machine learning scientist\n                      \n                        AI engineer\n                       \n                    Not sure?\n                   Take a career quiz  \n                Bootcamp\n               We are accredited by  \n          Resources  Resources\n             \n                Projects\n               \n                Career Kit  Career Kit\n                   Career Kit \n                        Interview Simulator\n                       \n                        Career Quiz\n                       \n                        Career Guides\n                       \n                Study Kit  Study Kit\n                   Study Kit \n                        Flashcards\n                       \n                        Course Notes\n                       \n                        Practice Exams\n                       \n                        Infographics\n                       \n                        Coding Templates\n                       \n                Blog\n               \n          Student Outcomes  Student Outcomes\n             \n                Reviews\n               \n                Student Stories\n               \n                Student Outcomes Report\n               \n          Pricing\n         \n          For Business\n         \n          Log in\n         \n          Start free\n           \n            Courses Library\n           \n            Discover a content-rich data science curriculum designed to build your skillset from\n            beginner to job-ready and help you achieve your data science career goals.\n            \n    Filter by\n   \n          Topics\n          Data LiteracyData PreprocessingData AnalysisMachine and Deep LearningAIData VisualizationProgrammingMath & StatisticsBusiness SkillsFinance SkillsData EngineeringCareer DevelopmentDashboard ReportingSpreadsheetsIndustry SpecializationSoft skillsFinance TheoryCloud ComputingMLOps \n          Technology\n          pythonSQLrexceltableauPower BIgittheorygoogle sheetsChatGPTLangChainapache airflowLangGraphAWScopilot \n          Level of difficulty\n          BasicIntermediateAdvanced \n          Duration\n          1-2 hours3-4 hours5-6 hours7+ hours \n          Career Track\n          Data ScientistData AnalystBusiness AnalystAI EngineerData EngineerSenior Data AnalystTableau DeveloperPower BI DeveloperMachine Learning ScientistSenior Data Scientist      \n      120 results\n    \n    \n          bestseller\n   \n            Introduction to Data and Data Science\n           \n            with Martin Ganchev, Iliya Valchanov\n           4.8/5                 (17,562)  \n            3 hours of content\n                 trending topic\n   \n            Intro to AI\n           \n            with Ned Krastev\n           4.9/5                 (1,720)  \n            2 hours of content\n                  \n            AI Strategy\n           \n            with Bernard Marr\n           0/5                   \n            4 hours of content\n                  \n            Intro to AI Agents and Agentic AI\n           \n            with Ned Krastev\n           4.8/5                 (534)  \n            2 hours of content\n                 popular\n   \n            Data  ...
#  Document(page_content='popular\n   \n            Data Strategy\n           \n            with Bernard Marr\n           4.8/5                 (3,357)  \n            6 hours of content\n                 bestseller\n   \n            Introduction to Excel\n           \n            with Ned Krastev\n           4.8/5                 (11,529)  \n            6 hours of content\n                  \n            Data Literacy\n           \n            with Olivier Maugain\n           4.8/5                 (2,034)  \n            5 hours of content\n                  \n            Introduction to Data Architecture\n           \n            with Rahul Singh\n           4.7/5                 (161)  \n            1 hour of content\n                 popular\n   \n            Data Analysis with Excel Pivot Tables\n           \n            with Ned Krastev\n           4.8/5                 (4,456)  \n            2 hours of content\n                  \n            Advanced Microsoft Excel\n           \n            with Ned Krastev, Martin Ganchev\n           4.8/5                 (2,394)  \n            3 hours of content\n                  \n            Copilot in Excel\n           \n            with Ivan Kitov\n           4.1/5                 (7)  \n            2 hours of content\n                 bestseller\n   \n            Statistics\n           \n            with Iliya Valchanov\n           4.8/5                 (5,841)  \n            5 hours of content\n                 trending topic\n   \n            Intro to ChatGPT and Generative AI\n           \n            with Ned Krastev\n           4.8/5                 (5,107)  \n            2 hours of content\n                  \n            Data Analysis with ChatGPT\n           \n            with Ned Krastev\n           4.8/5                 (929)  \n            2 hours of content\n                  \n            ChatGPT for SQL Beginners\n           \n            with Ivan Manov\n           4.9/5                 (145)  \n            1 hour of content\n                 new\n   \n            ChatGPT at Work: Ethical and Secure ChatGPT Use\n           \n            with Ned Krastev, Ivan Manov\n           4.9/5                 (91)  \n            2 hours of content\n                  \n            Probability\n           \n            with Viktor Mehandzhiyski\n           4.8/5                 (1,591)  \n            5 hours of content\n                 popular\n   \n            Mathematics\n           \n            with Iliya Valchanov\n           4.8/5                 (2,815)  \n            1 hour of content\n                  \n            Introduction to Tableau\n           \n            with Ned Krastev\n           4.8/5                 (1,906)  \n            2 hours of content\n                  \n            Power BI\n           \n            with Dimitar Shutev\n           4.8/5                 (3,431)  \n            8 hours of content\n                  \n            Power BI Data Visualization Hero\n           \n            with Alex Kolokolov\n           4.8/5                 (33)  \n            3 hours of content\n                 popular\n   \n            Starting a Career in Data Science: Project Portfolio, Resume, and Interview Process\n           \n            with Ken Jee\n           4.8/5                 (863)  \n            4 hours of content\n                  \n            SQL for Data Science Interviews\n           \n            with Tina Huang\n           4.8/5                 (797)  \n            2 hours of content\n                 new\n   \n            Python Coding Interview Prep\n           \n            with Joy Harjanto\n           4.8/5                 (61)  \n            1 hour of content\n                 popular\n   \n            How to Think Like a Data Scientist to Become One\n           \n            with Harpreet Sahota\n           4.8/5                 (976)  \n            3 hours of content\n                  \n            Intro to Shell\n           \n     ...
#  Document(page_content="Intro to Shell\n           \n            with Thomas Nield\n           4.8/5                 (55)  \n            1 hour of content\n                 new\n   \n            Understanding Cloud Computing\n           \n            with Andrew Jones\n           4.6/5                 (135)  \n            1 hour of content\n                  \n            Introduction to AWS Cloud\n           \n            with Ernest Asena\n           4.8/5                 (33)  \n            2 hours of content\n                  \n            Intro to Microsoft Azure\n           \n            with Andrew Jones\n           4.7/5                 (40)  \n            4 hours of content\n                  \n            Intro to Google Cloud\n           \n            with Samantha Guerriero\n           4.5/5                 (20)  \n            3 hours of content\n                 trending topic\n   \n            Intro to Data Engineering\n           \n            with Shashank Kalanithi\n           4.8/5                 (427)  \n            4 hours of content\n                 new\n   \n            Introduction to Data Warehousing\n           \n            with Rahul Singh\n           4.8/5                 (82)  \n            3 hours of content\n                 bestseller\n   \n            SQL\n           \n            with Martin Ganchev, Vladimir Saev\n           4.8/5                 (5,166)  \n            13 hours of content\n                  \n            Advanced SQL\n           \n            with Martin Ganchev, Vladimir Saev\n           4.8/5                 (594)  \n            7 hours of content\n                  \n            SQL + Tableau\n           \n            with Martin Ganchev\n           4.8/5                 (797)  \n            5 hours of content\n                  \n            Introduction to Databricks\n           \n            with Dimitar Shutev\n           4.7/5                 (57)  \n            2 hours of content\n                  \n            Introduction to Jupyter\n           \n            with Martin Ganchev\n           4.8/5                 (4,217)  \n            2 hours of content\n                 bestseller\n   \n            Introduction to Python\n           \n            with Martin Ganchev\n           4.8/5                 (5,419)  \n            2 hours of content\n                 bestseller\n   \n            Python Programmer Bootcamp\n           \n            with Giles McMullen-Klein\n           4.8/5                 (3,714)  \n            20 hours of content\n                  \n            Python 101: Kickoff\n           \n            with Hristina Hristova\n           4.8/5                 (82)  \n            2 hours of content\n                 new\n   \n            Python 102: Beginner's Power-Up\n           \n            with Hristina Hristova\n           4.8/5                 (45)  \n            2 hours of content\n                 new\n   \n            Introducing Algorithms in Python\n           \n            with Muhammad Ateeq\n           4.8/5                 (44)  \n            2 hours of content\n                  \n            Intermediate Python Programming\n           \n            with Martin Ganchev\n           4.8/5                 (902)  \n            1 hour of content\n                  \n            Git and GitHub\n           \n            with Giles McMullen-Klein\n           4.7/5                 (2,361)  \n            1 hour of content\n                  \n            Introduction to R Programming\n           \n            with Simona Dobreva, Iliya Valchanov\n           4.8/5                 (864)  \n            6 hours of content\n                  \n            The Complete Data Visualization Course with Python, R, Tableau, and Excel\n           \n            with Elitsa Kaloyanova\n           4.8/5                 (1,463)  \n            10 hours of content\n                  \n            Data Preprocessing with NumPy\n           \n            with Vi ...
#  Document(page_content='Data Preprocessing with NumPy\n           \n            with Viktor Mehandzhiyski\n           4.8/5                 (1,127)  \n            8 hours of content\n                  \n            Data Cleaning and Preprocessing with pandas\n           \n            with Martin Ganchev\n           4.7/5                 (1,991)  \n            3 hours of content\n                 top-rated\n   \n            Dates and Times in Python\n           \n            with Ivan Manov, Martin Ganchev\n           4.9/5                 (371)  \n            3 hours of content\n                  \n            Working with Text Files in Python\n           \n            with Martin Ganchev\n           4.8/5                 (446)  \n            1 hour of content\n                  \n            Power Query and Data Modeling\n           \n            with Dimitar Shutev\n           4.8/5                 (1,065)  \n            2 hours of content\n                  \n            Introduction to DAX\n           \n            with Dimitar Shutev\n           4.8/5                 (680)  \n            3 hours of content\n                  \n            Building Business Reports Using Power BI\n           \n            with Dimitar Shutev\n           4.8/5                 (785)  \n            2 hours of content\n                 trending topic\n   \n            Build Chat Applications with OpenAI and LangChain\n           \n            with Hristina Hristova\n           4.8/5                 (295)  \n            7 hours of content\n                 trending topic\n   \n            Build Conversational AI Memory with LangGraph\n           \n            with Hristina Hristova\n           4.9/5                 (53)  \n            2 hours of content\n                  \n            MCPs for Everyone: Supercharge Your AI Tooling Skills\n           \n            with Shoumik Goswami\n           4.7/5                 (33)  \n            9 hours of content\n                  \n            Introduction to Hugging Face\n           \n            with Lauren Newbould\n           4.6/5                 (81)  \n            2 hours of content\n                 trending topic\n   \n            LLM Engineering in Practice with Streamlit and OpenAI\n           \n            with Petar Petrov\n           4.8/5                 (121)  \n            4 hours of content\n                  \n            Introduction to Vector Databases with Pinecone\n           \n            with Elitsa Kaloyanova\n           4.8/5                 (188)  \n            2 hours of content\n                  \n            Evaluating AI Agents: From Metrics to Real-World Impact\n           \n            with Burcin Sarac\n           4.9/5                 (26)  \n            2 hours of content\n                  \n            AI Model deployment on AWS\n           \n            with Stefan Micic\n           4.7/5                 (54)  \n            1 hour of content\n                  \n            Machine Learning in Python\n           \n            with Iliya Valchanov\n           4.8/5                 (1,714)  \n            7 hours of content\n                 popular\n   \n            The Machine Learning Process A-Z\n           \n            with Ken Jee, Jeff Li\n           4.8/5                 (1,158)  \n            6 hours of content\n                  \n            The Machine Learning Algorithms A-Z\n           \n            with Jeff Li, Ken Jee\n           4.7/5                 (710)  \n            5 hours of content\n                  \n            Machine Learning Deep Dive: Business Applications and Coding Walkthroughs\n           \n            with Jeff Li, Ken Jee\n           4.8/5                 (262)  \n            3 hours of content\n                 new\n   \n            Fully Automated MLOps\n           \n            with Stefan Micic\n           4.5/5                 (76)  \n            1 hour of content\n                  \n            Machine Learning with  ...
#  Document(page_content='Machine Learning with Naïve Bayes\n           \n            with Hristina Hristova\n           4.8/5                 (788)  \n            2 hours of content\n                  \n            Machine Learning with K-Nearest Neighbors\n           \n            with Hristina Hristova\n           4.8/5                 (680)  \n            2 hours of content\n                  \n            Machine Learning with Decision Trees and Random Forests\n           \n            with Nikola Pulev\n           4.8/5                 (710)  \n            1 hour of content\n                  \n            Machine Learning with Support Vector Machines\n           \n            with Elitsa Kaloyanova\n           4.8/5                 (636)  \n            1 hour of content\n                  \n            Machine Learning with Ridge and Lasso Regression\n           \n            with Ivan Manov\n           4.8/5                 (376)  \n            1 hour of content\n                  \n            ChatGPT for Data Science\n           \n            with Elitsa Kaloyanova\n           4.8/5                 (294)  \n            2 hours of content\n                  \n            Linear Algebra and Feature Selection\n           \n            with Aleksandar Samsiev, Ivan Manov\n           4.7/5                 (454)  \n            3 hours of content\n                 new\n   \n            Math Foundation for ML\n           \n            with Neha Bansal\n           4.4/5                 (86)  \n            1 hour of content\n                  \n            Deep Learning with Pytorch\n           \n            with Gaurav Sarkar\n           4.5/5                 (48)  \n            2 hours of content\n                  \n            Deep Learning with TensorFlow 2\n           \n            with Iskren Vankov, Iliya Valchanov\n           4.8/5                 (1,025)  \n            5 hours of content\n                  \n            Convolutional Neural Networks with TensorFlow in Python\n           \n            with Nikola Pulev, Iskren Vankov\n           4.8/5                 (549)  \n            4 hours of content\n                  \n            Speech Recognition with Python\n           \n            with Ivan Manov\n           4.8/5                 (38)  \n            3 hours of content\n                  \n            SQL + Tableau + Python\n           \n            with Martin Ganchev\n           4.8/5                 (496)  \n            5 hours of content\n                 top-rated\n   \n            Machine Learning in Excel\n           \n            with Ivan Kitov\n           4.9/5                 (596)  \n            7 hours of content\n                  \n            Intro to NLP for AI\n           \n            with Lauren Newbould\n           4.8/5                 (630)  \n            4 hours of content\n                  \n            Intro to LLMs\n           \n            with Lauren Newbould\n           4.7/5                 (485)  \n            3 hours of content\n                 new\n   \n            Introduction to LLaMA\n           \n            with Jaleed Khan, PhD\n           4.7/5                 (43)  \n            2 hours of content\n                  \n            Communication and Presentation Skills for Analysts and Managers\n           \n            with Gilbert Eijkelenboom\n           4.8/5                 (739)  \n            3 hours of content\n                  \n            Data Ingestion with Pandas\n           \n            with Samson Afolabi\n           4.5/5                 (73)  \n            1 hour of content\n                  \n            Advanced SQL for Data Engineering\n           \n            with Shashank Kalanithi\n           4.8/5                 (482)  \n            2 hours of content\n                 new\n   \n            Building Data Pipelines with Apache Airflow\n           \n            with Shashank Kalanithi\n           4.6/5                 (83)  \n            2 ...
#  Document(page_content='with Shashank Kalanithi\n           4.6/5                 (83)  \n            2 hours of content\n                  \n            Python for Social Media Analytics\n           \n            with Natassha Selvaraj\n           4.8/5                 (229)  \n            2 hours of content\n                  \n            Intro to Revenue Analytics\n           \n            with Sudhir Buddhavarapu\n           4.7/5                 (239)  \n            1 hour of content\n                 new\n   \n            Intermediate Revenue Analytics\n           \n            with Sudhir Buddhavarapu\n           4.8/5                 (74)  \n            1 hour of content\n                  \n            Data-Driven Business Growth\n           \n            with Davis Balaba, Tina Huang\n           4.7/5                 (381)  \n            4 hours of content\n                  \n            A/B Testing in Python\n           \n            with Anastasia Kuznetsova\n           4.7/5                 (646)  \n            3 hours of content\n                 top-rated\n   \n            Statistical Tests in Sales and Marketing\n           \n            with Olivier Maugain, Aastik Malhotra, Ivan Manov\n           4.9/5                 (138)  \n            3 hours of content\n                 top-rated\n   \n            Growth Analysis with SQL, Python, and Tableau  \n           \n            with Nikola Pulev\n           4.9/5                 (91)  \n            4 hours of content\n                  \n            Customer Churn Analysis with SQL and Tableau\n           \n            with Elitsa Kaloyanova\n           4.8/5                 (299)  \n            3 hours of content\n                 top-rated\n   \n            Customer Engagement Analysis with SQL and Tableau\n           \n            with Hristina Hristova\n           4.9/5                 (162)  \n            5 hours of content\n                 top-rated\n   \n            Sign-Up Flow Optimization Analysis with SQL and Tableau\n           \n            with Ivan Manov\n           4.9/5                 (100)  \n            4 hours of content\n                  \n            Fashion Analytics with Tableau\n           \n            with Elitsa Kaloyanova\n           4.8/5                 (263)  \n            3 hours of content\n                  \n            AI Applications for Business Success\n           \n            with Horia Mărgărit\n           4.7/5                 (405)  \n            2 hours of content\n                 top-rated\n   \n            Customer Analytics in Python\n           \n            with Nikolay Georgiev, Elitsa Kaloyanova\n           4.9/5                 (413)  \n            10 hours of content\n                  \n            Econometrics I\n           \n            with Professor Gerhard Kling\n           4.9/5                 (26)  \n            2 hours of content\n                 top-rated\n   \n            Credit Risk Modeling in Python\n           \n            with Nikolay Georgiev\n           4.9/5                 (441)  \n            8 hours of content\n                  \n            Time Series Analysis with Python\n           \n            with Viktor Mehandzhiyski\n           4.8/5                 (575)  \n            7 hours of content\n                  \n            Advanced Time Series Analysis with Python\n           \n            with Egor Howell\n           5/5                 (1)  \n            6 hours of content\n                  \n            Web Scraping and API Fundamentals in Python\n           \n            with Andrew Treadway, Nikola Pulev\n           4.8/5                 (575)  \n            4 hours of content\n                  \n            Python for Finance\n           \n            with Martin Ganchev, Ned Krastev\n           4.8/5                 (475)  \n            6 hours of content\n                  \n            Introduction to Business Analytics\n           \n            with Randy Ro ...
#  Document(page_content='Introduction to Business Analytics\n           \n            with Randy Rosseel\n           4.8/5                 (1,248)  \n            6 hours of content\n                 top-rated\n   \n            Product Management for AI & Data Science\n           \n            with Danielle Thé\n           4.8/5                 (808)  \n            6 hours of content\n                 trending topic\n   \n            AI Ethics\n           \n            with Ned Krastev, Ivan Manov\n           4.9/5                 (83)  \n            4 hours of content\n                  \n            Data Analysis in PowerBI with ChatGPT\n           \n            with Dimitar Shutev\n           4.8/5                 (764)  \n            1 hour of content\n                  \n            Mastering Key Performance Indicators (KPIs)\n           \n            with Bernard Marr\n           4.8/5                 (624)  \n            3 hours of content\n                  \n            Blockchain for Business\n           \n            with Peter Lipovyanov\n           4.9/5                 (408)  \n            5 hours of content\n                  \n            Project Management\n           \n            with Ivan Vaptsarov\n           4.8/5                 (446)  \n            4 hours of content\n                  \n            Corporate Strategy\n           \n            with Valentina Bogdanova\n           4.8/5                 (296)  \n            2 hours of content\n                  \n            Marketing Strategy\n           \n            with Valentina Bogdanova\n           4.8/5                 (207)  \n            2 hours of content\n                  \n            Negotiation\n           \n            with Valentina Bogdanova\n           4.9/5                 (150)  \n            1 hour of content\n                  \n            Excel for Project Management\n           \n            with Ivan Vaptsarov\n           4.8/5                 (81)  \n            1 hour of content\n                  \n            Agile and Scrum Project Management\n           \n            with Ivan Vaptsarov\n           4.8/5                 (83)  \n            1 hour of content\n                  \n            Management\n           \n            with Valentina Bogdanova\n           4.9/5                 (53)  \n            1 hour of content\n                  \n            Persuasion and Influence\n           \n            with Valentina Bogdanova\n           4.8/5                 (64)  \n            1 hour of content\n             \n          Join 3M Learners on their Quest for Success\n         \n          Take data science courses from expert instructors from\n          \n          Develop an invaluable skillset and land your dream job in data and AI.\n         \n          Start Now\n            \n        where your new AI and data science career starts\n         \n              Company\n             \n                  About us\n                \n                  Reviews\n                \n                  Student stories\n                \n                  Student outcomes report\n                \n                  Meet the instructors\n                \n                  Become an instructor\n                \n                  Pricing\n                \n              Learn\n             \n                  Courses\n                \n                  Career tracks\n                \n                  Bootcamp\n                \n                  Certificates\n                \n              Resources\n             \n                  Projects\n                \n                  Interview simulator\n                \n                  Career quiz\n                \n                  Career guides\n                \n                  Flashcards\n                \n                  Course notes\n                \n                  Infographics\n                \n                  Coding templates\n                \n                  B ...
#  Document(page_content='Blog\n                \n              Support\n             \n                  Contact us\n                \n                  Help center\n                \n                  Verify certificate\n                \n              For business\n             \n                  Corporate training\n                \n                  Team plan\n                 \n                Company\n               \n                    About us\n                  \n                    Reviews\n                  \n                    Student stories\n                  \n                    Student outcomes report\n                  \n                    Meet the instructors\n                  \n                    Become an instructor\n                  \n                    Pricing\n                  \n                Resources\n               \n                    Projects\n                  \n                    Interview simulator\n                  \n                    Career quiz\n                  \n                    Career guides\n                  \n                    Flashcards\n                  \n                    Course notes\n                  \n                    Infographics\n                  \n                    Coding templates\n                  \n                    Blog\n                   \n                Learn\n               \n                    Courses\n                  \n                    Career tracks\n                  \n                    Bootcamp\n                  \n                    Certificates\n                  \n                For business\n               \n                    Corporate training\n                  \n                    Team plan\n                  \n                Support\n               \n                    Contact us\n                  \n                    Help center\n                  \n                    Verify certificate\n                     \n            4.9\n             Based on 808 reviews \n          © 2025 365 Data Science. All Rights Reserved.\n         \n            Sitemap\n           \n            Terms of Use\n           \n            Privacy Policy\n           \n            Cookies', metadata={'source': 'https://365datascience.com/upcoming-courses', 'title': 'Online Data Science Courses and Certification – 365 Data Science', 'description': 'Browse various data science courses on in-demand tools like SQL, Python, and R. Discover the perfect structured training program for beginners. Start now!', 'language': 'en'})]

# %%
embeddings = OpenAIEmbeddings(openai_api_key=api_key)

# %%
vectorstore = FAISS.from_documents(documents, embeddings)

# %%
memory = ConversationBufferMemory(memory_key='chat_history', return_messages=True)

# %%
qa = ConversationalRetrievalChain.from_llm(
    ChatOpenAI(
        openai_api_key=api_key,
        model="gpt-3.5-turbo",
        temperature=0
    ),
    vectorstore.as_retriever(),
    memory=memory
)

# %%
query = " What is the next course to be uploaded on the 365DataScience platform?"

# %%
result = qa({"question": query})

# %%
result["answer"]
# Out:
# "I'm sorry, but I don't have access to real-time updates on course uploads on the 365DataScience platform. It would be best to check their website or contact their support team for the most up-to-date information on upcoming courses."
